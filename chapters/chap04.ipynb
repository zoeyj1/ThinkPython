# %% [markdown]
# You can order print and ebook versions of *Think Python 3e* from
# [Bookshop.org](https://bookshop.org/a/98697/9781098155438) and
# [Amazon](https://www.amazon.com/_/dp/1098155432?smid=ATVPDKIKX0DER&_encoding=UTF8&tag=oreilly20-20&_encoding=UTF8&tag=greenteapre01-20&linkCode=ur2&linkId=e2a529f94920295d27ec8a06e757dc7c&camp=1789&creative=9325).

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Downloaded " + str(local))
    return filename

download('https://github.com/AllenDowney/ThinkPython/raw/v3/thinkpython.py');
download('https://github.com/AllenDowney/ThinkPython/raw/v3/diagram.py');
download('https://github.com/ramalho/jupyturtle/releases/download/2024-03/jupyturtle.py');
# Out:
# Downloaded thinkpython.py
# Downloaded diagram.py
# Downloaded jupyturtle.py

# %%
import thinkpython

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Functions and Interfaces
#
# This chapter introduces a module called `jupyturtle`, which allows you to create simple drawings by giving instructions to an imaginary turtle.
# We will use this module to write functions that draw squares, polygons, and circles -- and to demonstrate **interface design**, which is a way of designing functions that work together.

# %% [markdown]
# ## The jupyturtle module
#
# To use the `jupyturtle` module, we can import it like this.

# %%
import jupyturtle

# %% [markdown]
# Now we can use the functions defined in the module, like `make_turtle` and `forward`.

# %%
jupyturtle.make_turtle()
jupyturtle.forward(100)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="250.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,250.0,75.0) translate(250.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# `make_turtle` creates a **canvas**, which is a space on the screen where we can draw, and a turtle, which is represented by a circular shell and a triangular head.
# The circle shows the location of the turtle and the triangle indicates the direction it is facing.
#
# `forward` moves the turtle a given distance in the direction it's facing, drawing a line segment along the way.
# The distance is in arbitrary units -- the actual size depends on your computer's screen.
#
# We will use functions defined in the `jupyturtle` module many times, so it would be nice if we did not have to write the name of the module every time.
# That's possible if we import the module like this.

# %%
from jupyturtle import make_turtle, forward

# %% [markdown]
# This version of the import statement imports `make_turtle` and `forward` from the `jupyturtle` module so we can call them like this.

# %%
make_turtle()
forward(100)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="250.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,250.0,75.0) translate(250.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# `jupyturtle` provides two other functions we'll use, called `left` and `right`.
# We'll import them like this.

# %%
from jupyturtle import left, right

# %% [markdown]
# `left` causes the turtle to turn left. It takes one argument, which is the angle of the turn in degrees.
# For example, we can make a 90 degree left turn like this.

# %%
make_turtle()
forward(50)
left(90)
forward(50)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(180.0,200.0,25.0) translate(200.0, 25.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# This program moves the turtle east and then north, leaving two line segments behind.
# Before you go on, see if you can modify the previous program to make a square.

# %% [markdown]
# ## Making a square
#
# Here's one way to make a square.

# %%
make_turtle()

forward(50)
left(90)

forward(50)
left(90)

forward(50)
left(90)

forward(50)
left(90)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="25.0" x2="150.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="25.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Because this program repeats the same pair of lines four times, we can do the same thing more concisely with a `for` loop.

# %%
make_turtle()
for i in range(4):
    forward(50)
    left(90)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="25.0" x2="150.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="25.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ## Encapsulation and generalization
#
# Let's take the square-drawing code from the previous section and put it in a function called `square`.

# %%
def square():
    for i in range(4):
        forward(50)
        left(90)

# %% [markdown]
# Now we can call the function like this.

# %%
make_turtle()
square()
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="200.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="25.0" x2="150.0" y2="25.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="25.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Wrapping a piece of code up in a function is called **encapsulation**.
# One of the benefits of encapsulation is that it attaches a name to the code, which serves as a kind of documentation. Another advantage is that if you re-use the code, it is more concise to call a function twice than to copy and paste the body!
#
# In the current version, the size of the square is always `50`.
# If we want to draw squares with different sizes, we can take the length of the sides as a parameter.

# %%
def square(length):
    for i in range(4):
        forward(length)
        left(90)

# %% [markdown]
# Now we can draw squares with different sizes.

# %%
make_turtle()
square(30)
square(60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="180.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="75.0" x2="180.0" y2="45.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="45.0" x2="150.0" y2="45.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="45.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="210.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.0" y1="75.0" x2="210.0" y2="15.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.0" y1="15.0" x2="150.0" y2="15.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="15.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# Adding a parameter to a function is called **generalization** because it makes the function more general: with the previous version, the square is always the same size; with this version it can be any size.
#
# If we add another parameter, we can make it even more general.
# The following function draws regular polygons with a given number of sides.

# %%
def polygon(n, length):
    angle = 360 / n
    for i in range(n):
        forward(length)
        left(angle)

# %% [markdown]
# In a regular polygon with `n` sides, the angle between adjacent sides is `360 / n` degrees.
#
# The following example draws a `7`-sided polygon with side length `30`.

# %%
make_turtle()
polygon(7, 30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="180.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="75.0" x2="198.7" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.7" y1="51.5" x2="192.0" y2="22.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.0" y1="22.3" x2="165.0" y2="9.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.0" y1="9.3" x2="138.0" y2="22.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.0" y1="22.3" x2="131.3" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.3" y1="51.5" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(270.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# When a function has more than a few numeric arguments, it is easy to forget what they are, or what order they should be in.
# It can be a good idea to include the names of the parameters in the argument list.

# %%
make_turtle()
polygon(n=7, length=30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="180.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="75.0" x2="198.7" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.7" y1="51.5" x2="192.0" y2="22.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.0" y1="22.3" x2="165.0" y2="9.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.0" y1="9.3" x2="138.0" y2="22.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.0" y1="22.3" x2="131.3" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.3" y1="51.5" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(270.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# These are sometimes called "named arguments" because they include the parameter names.
# But in Python they are more often called **keyword arguments** (not to be confused with Python keywords like `for` and `def`).
#
# This use of the assignment operator, `=`, is a reminder about how arguments and parameters work -- when you call a function, the arguments are assigned to the parameters.

# %% [markdown]
# ## Approximating a circle
#
# Now suppose we want to draw a circle.
# We can do that, approximately, by drawing a polygon with a large number of sides, so each side is small enough that it's hard to see.
# Here is a function that uses `polygon` to draw a `30`-sided polygon that approximates a circle.

# %%
import math

def circle(radius):
    circumference = 2 * math.pi * radius
    n = 30
    length = circumference / n
    polygon(n, length)

# %% [markdown]
# `circle` takes the radius of the the circle as a parameter.
# It computes `circumference`, which is the circumference of a circle with the given radius.
# `n` is the number of sides, so `circumference / n` is the length of each side.
#
# This function might take a long time to run.
# We can speed it up by calling `make_turtle` with a keyword argument called `delay` that sets the time, in seconds, the turtle waits after each step.
# The default value is `0.2` seconds -- if we set it to `0.02` it runs about 10 times faster.

# %%
make_turtle(delay=0.02)
circle(30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="156.3" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.3" y1="75.0" x2="162.4" y2="73.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.4" y1="73.7" x2="168.2" y2="71.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.2" y1="71.1" x2="173.3" y2="67.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.3" y1="67.4" x2="177.5" y2="62.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.5" y1="62.8" x2="180.6" y2="57.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.6" y1="57.3" x2="182.5" y2="51.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.5" y1="51.4" x2="183.2" y2="45.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.2" y1="45.1" x2="182.5" y2="38.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.5" y1="38.9" x2="180.6" y2="32.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.6" y1="32.9" x2="177.5" y2="27.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.5" y1="27.4" x2="173.3" y2="22.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.3" y1="22.8" x2="168.2" y2="19.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.2" y1="19.1" x2="162.4" y2="16.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.4" y1="16.5" x2="156.3" y2="15.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.3" y1="15.2" x2="150.0" y2="15.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="15.2" x2="143.9" y2="16.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.9" y1="16.5" x2="138.1" y2="19.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.1" y1="19.1" x2="133.0" y2="22.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.0" y1="22.8" x2="128.8" y2="27.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.8" y1="27.4" x2="125.7" y2="32.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.7" y1="32.9" x2="123.7" y2="38.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.7" y1="38.9" x2="123.1" y2="45.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.1" y1="45.1" x2="123.7" y2="51.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.7" y1="51.4" x2="125.7" y2="57.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.7" y1="57.3" x2="128.8" y2="62.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.8" y1="62.8" x2="133.0" y2="67.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.0" y1="67.4" x2="138.1" y2="71.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.1" y1="71.1" x2="143.9" y2="73.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.9" y1="73.7" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# A limitation of this solution is that `n` is a constant, which means
# that for very big circles, the sides are too long, and for small
# circles, we waste time drawing very short sides.
# One option is to generalize the function by taking `n` as a parameter.
# But let's keep it simple for now.

# %% [markdown]
# ## Refactoring
#
# Now let's write a more general version of `circle`, called `arc`, that takes a second parameter, `angle`, and draws an arc of a circle that spans the given angle.
# For example, if `angle` is `360` degrees, it draws a complete circle. If `angle` is `180` degrees, it draws a half circle.
#
# To write `circle`, we were able to reuse `polygon`, because a many-sided polygon is a good approximation of a circle.
# But we can't use `polygon` to write `arc`.
#
# Instead, we'll create the more general version of `polygon`, called `polyline`.

# %%
def polyline(n, length, angle):
    for i in range(n):
        forward(length)
        left(angle)

# %% [markdown]
# `polyline` takes as parameters the number of line segments to draw, `n`, the length of the segments, `length`, and the angle between them, `angle`.
#
# Now we can rewrite `polygon` to use `polyline`.

# %%
def polygon(n, length):
    angle = 360.0 / n
    polyline(n, length, angle)

# %% [markdown]
# And we can use `polyline` to write `arc`.

# %%
def arc(radius, angle):
    arc_length = 2 * math.pi * radius * angle / 360
    n = 30
    length = arc_length / n
    step_angle = angle / n
    polyline(n, length, step_angle)

# %% [markdown]
# `arc` is similar to `circle`, except that it computes `arc_length`, which is a fraction of the circumference of a circle.
#
# Finally, we can rewrite `circle` to use `arc`.

# %%
def circle(radius):
    arc(radius,  360)

# %% [markdown]
# To check that these functions work as expected, we'll use them to draw something like a snail.
# With `delay=0`, the turtle runs as fast as possible.

# %%
make_turtle(delay=0)
polygon(n=20, length=9)
arc(radius=70, angle=70)
circle(radius=10)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="159.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.0" y1="75.0" x2="167.6" y2="72.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.6" y1="72.2" x2="174.8" y2="66.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="174.8" y1="66.9" x2="180.1" y2="59.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.1" y1="59.6" x2="182.9" y2="51.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.9" y1="51.1" x2="182.9" y2="42.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.9" y1="42.1" x2="180.1" y2="33.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.1" y1="33.5" x2="174.8" y2="26.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="174.8" y1="26.2" x2="167.6" y2="21.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.6" y1="21.0" x2="159.0" y2="18.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.0" y1="18.2" x2="150.0" y2="18.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="18.2" x2="141.4" y2="21.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.4" y1="21.0" x2="134.2" y2="26.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.2" y1="26.2" x2="128.9" y2="33.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.9" y1="33.5" x2="126.1" y2="42.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.1" y1="42.1" x2="126.1" y2="51.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.1" y1="51.1" x2="128.9" y2="59.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.9" y1="59.6" x2="134.2" y2="66.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.2" y1="66.9" x2="141.4" y2="72.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.4" y1="72.2" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="152.9" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.9" y1="75.0" x2="155.7" y2="74.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.7" y1="74.9" x2="158.5" y2="74.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.5" y1="74.7" x2="161.4" y2="74.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.4" y1="74.3" x2="164.2" y2="73.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.2" y1="73.8" x2="167.0" y2="73.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.0" y1="73.3" x2="169.7" y2="72.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="169.7" y1="72.6" x2="172.5" y2="71.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.5" y1="71.8" x2="175.2" y2="70.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.2" y1="70.9" x2="177.8" y2="69.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.8" y1="69.8" x2="180.5" y2="68.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.5" y1="68.7" x2="183.0" y2="67.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.0" y1="67.5" x2="185.5" y2="66.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.5" y1="66.1" x2="188.0" y2="64.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.0" y1="64.7" x2="190.4" y2="63.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.4" y1="63.2" x2="192.7" y2="61.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.7" y1="61.5" x2="195.0" y2="59.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="195.0" y1="59.8" x2="197.2" y2="58.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.2" y1="58.0" x2="199.3" y2="56.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="199.3" y1="56.1" x2="201.4" y2="54.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.4" y1="54.1" x2="203.3" y2="52.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.3" y1="52.0" x2="205.2" y2="49.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="205.2" y1="49.9" x2="207.0" y2="47.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="207.0" y1="47.6" x2="208.7" y2="45.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="208.7" y1="45.3" x2="210.2" y2="43.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.2" y1="43.0" x2="211.7" y2="40.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="211.7" y1="40.5" x2="213.1" y2="38.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="213.1" y1="38.1" x2="214.4" y2="35.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="214.4" y1="35.5" x2="215.6" y2="32.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="215.6" y1="32.9" x2="216.7" y2="30.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="216.7" y1="30.3" x2="217.4" y2="28.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="217.4" y1="28.3" x2="217.7" y2="26.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="217.7" y1="26.2" x2="217.6" y2="24.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="217.6" y1="24.2" x2="217.0" y2="22.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="217.0" y1="22.1" x2="216.0" y2="20.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="216.0" y1="20.3" x2="214.7" y2="18.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="214.7" y1="18.7" x2="213.0" y2="17.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="213.0" y1="17.4" x2="211.1" y2="16.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="211.1" y1="16.5" x2="209.1" y2="16.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="209.1" y1="16.0" x2="207.0" y2="15.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="207.0" y1="15.9" x2="204.9" y2="16.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="204.9" y1="16.3" x2="203.0" y2="17.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.0" y1="17.0" x2="201.3" y2="18.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.3" y1="18.2" x2="199.8" y2="19.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="199.8" y1="19.7" x2="198.7" y2="21.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.7" y1="21.5" x2="198.0" y2="23.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.0" y1="23.5" x2="197.7" y2="25.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.7" y1="25.5" x2="197.8" y2="27.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.8" y1="27.6" x2="198.4" y2="29.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.4" y1="29.6" x2="199.4" y2="31.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="199.4" y1="31.5" x2="200.7" y2="33.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.7" y1="33.1" x2="202.4" y2="34.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.4" y1="34.4" x2="204.3" y2="35.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="204.3" y1="35.3" x2="206.3" y2="35.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="206.3" y1="35.8" x2="208.4" y2="35.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="208.4" y1="35.9" x2="210.5" y2="35.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.5" y1="35.5" x2="212.4" y2="34.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="212.4" y1="34.7" x2="214.1" y2="33.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="214.1" y1="33.6" x2="215.6" y2="32.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="215.6" y1="32.1" x2="216.7" y2="30.3"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(200.0,216.7,30.3) translate(216.7, 30.3)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# In this example, we started with working code and reorganized it with different functions.
# Changes like this, which improve the code without changing its behavior, are called **refactoring**.
#
# If we had planned ahead, we might have written `polyline` first and avoided refactoring, but often you don't know enough at the beginning of a project to design all the functions.
# Once you start coding, you understand the problem better.
# Sometimes refactoring is a sign that you have learned something.

# %% [markdown]
# ## Stack diagram
#
# When we call `circle`, it calls `arc`, which calls `polyline`.
# We can use a stack diagram to show this sequence of function calls and the parameters for each one.

# %%
from diagram import make_binding, make_frame, Frame, Stack

frame1 = make_frame(dict(radius=30), name='circle', loc='left')

frame2 = make_frame(dict(radius=30, angle=360), name='arc', loc='left', dx=1.1)

frame3 = make_frame(dict(n=60, length=3.04, angle=5.8),
                    name='polyline', loc='left', dx=1.1, offsetx=-0.27)

stack = Stack([frame1, frame2, frame3], dy=-0.4)

# %%
from diagram import diagram, adjust

width, height, x, y = [3.58, 1.31, 0.98, 1.06]
ax = diagram(width, height)
bbox = stack.draw(ax, x, y)
#adjust(x, y, bbox)

# %% [markdown]
# Notice that the value of `angle` in `polyline` is different from the value of `angle` in `arc`.
# Parameters are local, which means you can use the same parameter name in different functions; it's a different variable in each function, and it can refer to a different value.

# %% [markdown]
# ## A development plan
#
# A **development plan** is a process for writing programs.
# The process we used in this chapter is "encapsulation and generalization".
# The steps of this process are:
#
# 1.  Start by writing a small program with no function definitions.
#
# 2.  Once you get the program working, identify a coherent piece of it,
#     encapsulate the piece in a function and give it a name.
#
# 3.  Generalize the function by adding appropriate parameters.
#
# 4.  Repeat Steps 1 to 3 until you have a set of working functions.
#
# 5.  Look for opportunities to improve the program by refactoring. For
#     example, if you have similar code in several places, consider
#     factoring it into an appropriately general function.
#
# This process has some drawbacks -- we will see alternatives later -- but it can be useful if you don't know ahead of time how to divide the program into functions.
# This approach lets you design as you go along.

# %% [markdown]
# The design of a function has two parts:
#
# * The **interface** is how the function is used, including its name, the parameters it takes and what the function is supposed to do.
#
# * The **implementation** is how the function does what it's supposed to do.
#
# For example, here's the first version of `circle` we wrote, which uses `polygon`.

# %%
def circle(radius):
    circumference = 2 * math.pi * radius
    n = 30
    length = circumference / n
    polygon(n, length)

# %% [markdown]
# And here's the refactored version that uses `arc`.

# %%
def circle(radius):
    arc(radius,  360)

# %% [markdown]
# These two functions have the same interface -- they take the same parameters and do the same thing -- but they have different implementations.

# %% [markdown]
# ## Docstrings
#
# A **docstring** is a string at the beginning of a function that explains the interface ("doc" is short for "documentation").
# Here is an example:

# %%
def polyline(n, length, angle):
    """Draws line segments with the given length and angle between them.

    n: integer number of line segments
    length: length of the line segments
    angle: angle between segments (in degrees)
    """
    for i in range(n):
        forward(length)
        left(angle)

# %% [markdown]
# By convention, docstrings are triple-quoted strings, also known as **multiline strings** because the triple quotes allow the string to span more than one line.
#
# A docstring should:
#
# * Explain concisely what the function does, without getting into the details of how it works,
#
# * Explain what effect each parameter has on the behavior of the function, and
#
# * Indicate what type each parameter should be, if it is not obvious.
#
# Writing this kind of documentation is an important part of interface design.
# A well-designed interface should be simple to explain; if you have a hard time explaining one of your functions, maybe the interface could be improved.

# %% [markdown]
# ## Debugging
#
# An interface is like a contract between a function and a caller. The
# caller agrees to provide certain arguments and the function agrees to
# do certain work.
#
# For example, `polyline` requires three arguments: `n` has to be an integer; `length` should be a positive number; and `angle` has to be a number, which is understood to be in degrees.
#
# These requirements are called **preconditions** because they are supposed to be true before the function starts executing. Conversely, conditions at the end of the function are **postconditions**.
# Postconditions include the intended effect of the function (like drawing line segments) and any side effects (like moving the turtle or making other changes).
#
# Preconditions are the responsibility of the caller. If the caller violates a precondition and the function doesn't work correctly, the bug is in the caller, not the function.
#
# If the preconditions are satisfied and the postconditions are not, the bug is in the function. If your pre- and postconditions are clear, they can help with debugging.

# %% [markdown]
# ## Glossary
#
# **interface design:**
# A process for designing the interface of a function, which includes the parameters it should take.
#
# **canvas:**
# A window used to display graphical elements including lines, circles, rectangles, and other shapes.
#
# **encapsulation:**
#  The process of transforming a sequence of statements into a function definition.
#
# **generalization:**
#  The process of replacing something unnecessarily specific (like a number) with something appropriately general (like a variable or parameter).
#
# **keyword argument:**
# An argument that includes the name of the parameter.
#
# **refactoring:**
#  The process of modifying a working program to improve function interfaces and other qualities of the code.
#
# **development plan:**
# A process for writing programs.
#
# **docstring:**
#  A string that appears at the top of a function definition to document the function's interface.
#
# **multiline string:**
# A string enclosed in triple quotes that can span more than one line of a program.
#
# **precondition:**
#  A requirement that should be satisfied by the caller before a function starts.
#
# **postcondition:**
#  A requirement that should be satisfied by the function before it ends.

# %% [markdown]
# ## Exercises

# %%
# This cell tells Jupyter to provide detailed debugging information
# when a runtime error occurs. Run it before working on the exercises.

# %xmode Verbose
# Out:
# Exception reporting mode: Verbose

# %% [markdown]
# For the exercises below, there are a few more turtle functions you might want to use.
#
# * `penup` lifts the turtle's imaginary pen so it doesn't leave a trail when it moves.
#
# * `pendown` puts the pen back down.
#
# The following function uses `penup` and `pendown` to move the turtle without leaving a trail.

# %%
from jupyturtle import penup, pendown

def jump(length):
    """Move forward length units without leaving a trail.

    Postcondition: Leaves the pen down.
    """
    penup()
    forward(length)
    pendown()

# %% [markdown]
# ### Exercise
#
# Write a function called `rectangle` that draws a rectangle with given side lengths.
# For example, here's a rectangle that's `80` units wide and `40` units tall.

# %%
# Solution goes here
def rectangle(width, height):
  for i in range(2):
    forward(width)
    left(90)
    forward(height)
    left(90)

# %% [markdown]
# You can use the following code to test your function.

# %%
make_turtle()
rectangle(80, 40)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="230.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="35.0" x2="150.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="35.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write a function called `rhombus` that draws a rhombus with a given side length and a given interior angle. For example, here's a rhombus with side length `50` and an interior angle of `60` degrees.

# %%
# Solution goes here
def rhombus(length, angle):
  for i in range(2):
    forward(length)
    left(180-angle)
    forward(length)
    left(angle)

# %% [markdown]
# You can use the following code to test your function.

# %%
make_turtle()
rhombus(50, 60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="175.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.0" y1="31.7" x2="125.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.0" y1="31.7" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Now write a more general function called `parallelogram` that draws a quadrilateral with parallel sides. Then rewrite `rectangle` and `rhombus` to use `parallelogram`.

# %%
# Solution goes here
def parallelogram(width, height, angle):
  for i in range(2):
    forward(width)
    left(180-angle)
    forward(height)
    left(angle)

# %%
# Solution goes here
def rectangle(width, height):
  parallelogram(width, height, 90)

# %%
# Solution goes here
def rhombus(length, angle):
  parallelogram(length, length, angle)

# %% [markdown]
# You can use the following code to test your functions.

# %%
make_turtle(width=400)
jump(-120)

rectangle(80, 40)
jump(100)
rhombus(50, 60)
jump(80)
parallelogram(80, 50, 60)
# Out:
# <svg width="400" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="80.0" y1="75.0" x2="160.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.0" y1="75.0" x2="160.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.0" y1="35.0" x2="80.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="80.0" y1="35.0" x2="80.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="75.0" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="205.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="205.0" y1="31.7" x2="155.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.0" y1="31.7" x2="180.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="260.0" y1="75.0" x2="340.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="340.0" y1="75.0" x2="315.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="315.0" y1="31.7" x2="235.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="235.0" y1="31.7" x2="260.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,260.0,75.0) translate(260.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercise
#
# Write an appropriately general set of functions that can draw shapes like this.
#
# ![](https://github.com/AllenDowney/ThinkPython/raw/v3/jupyturtle_pie.png)
#
# Hint: Write a function called `triangle` that draws one triangular segment, and then a function called `draw_pie` that uses `triangle`.

# %%
# Solution goes here

"this function creates a triangle segment with adjustable outer lengths and turn angles depending on how many segments are in the pie."

def triangle(n, length):
  inner_angle = 360/n
  outer_angle = (180 - inner_angle)/2
  outer_length = 2 * length * math.sin(math.radians(inner_angle / 2))

  forward(length)
  left(180-outer_angle)
  forward(outer_length)
  left(180-outer_angle)
  forward(length)
  left(180)

"""
sin of half of the inner angle in radians is O/H which is half of the outer length over the length
sin(inner angle / 2 in radians) = half of outer length / length
outer length = length * 2 * sin(inner angle/2 in radians)
"""

make_turtle()
triangle(7, 40)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="190.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="75.0" x2="174.9" y2="43.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="174.9" y1="43.7" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(218.6,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
# Solution goes here

def draw_pie(n, length):
  for i in range(n):
    # goes from 0 to n, repeating the triangle function for n times
    triangle(n, length)

make_turtle(delay=0.02)
draw_pie(8, 70)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="220.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="220.0" y1="75.0" x2="199.5" y2="25.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="199.5" y1="25.5" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="199.5" y2="25.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="199.5" y1="25.5" x2="150.0" y2="5.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="5.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="150.0" y2="5.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="5.0" x2="100.5" y2="25.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="100.5" y1="25.5" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="100.5" y2="25.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="100.5" y1="25.5" x2="80.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="80.0" y1="75.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="80.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="80.0" y1="75.0" x2="100.5" y2="124.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="100.5" y1="124.5" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="100.5" y2="124.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="100.5" y1="124.5" x2="150.0" y2="145.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="145.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="150.0" y2="145.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="145.0" x2="199.5" y2="124.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="199.5" y1="124.5" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="199.5" y2="124.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="199.5" y1="124.5" x2="220.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="220.0" y1="75.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# You can use the following code to test your functions.

# %%
turtle = make_turtle(delay=0)
jump(-80)

size = 40
draw_pie(5, size)
jump(2*size)
draw_pie(6, size)
jump(2*size)
draw_pie(7, size)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="70.0" y1="75.0" x2="110.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.0" y1="75.0" x2="82.4" y2="37.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="82.4" y1="37.0" x2="70.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="70.0" y1="75.0" x2="82.4" y2="37.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="82.4" y1="37.0" x2="37.6" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="37.6" y1="51.5" x2="70.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="70.0" y1="75.0" x2="37.6" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="37.6" y1="51.5" x2="37.6" y2="98.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="37.6" y1="98.5" x2="70.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="70.0" y1="75.0" x2="37.6" y2="98.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="37.6" y1="98.5" x2="82.4" y2="113.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="82.4" y1="113.0" x2="70.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="70.0" y1="75.0" x2="82.4" y2="113.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="82.4" y1="113.0" x2="110.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.0" y1="75.0" x2="70.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="190.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="75.0" x2="170.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="40.4" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="170.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="40.4" x2="130.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="40.4" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="130.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="40.4" x2="110.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.0" y1="75.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="110.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.0" y1="75.0" x2="130.0" y2="109.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="109.6" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="130.0" y2="109.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="109.6" x2="170.0" y2="109.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="109.6" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="170.0" y2="109.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="109.6" x2="190.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="75.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="270.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="270.0" y1="75.0" x2="254.9" y2="43.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="254.9" y1="43.7" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="254.9" y2="43.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="254.9" y1="43.7" x2="221.1" y2="36.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="221.1" y1="36.0" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="221.1" y2="36.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="221.1" y1="36.0" x2="194.0" y2="57.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.0" y1="57.6" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="194.0" y2="57.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.0" y1="57.6" x2="194.0" y2="92.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.0" y1="92.4" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="194.0" y2="92.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.0" y1="92.4" x2="221.1" y2="114.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="221.1" y1="114.0" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="221.1" y2="114.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="221.1" y1="114.0" x2="254.9" y2="106.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="254.9" y1="106.3" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="254.9" y2="106.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="254.9" y1="106.3" x2="270.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="270.0" y1="75.0" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(270.0,230.0,75.0) translate(230.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
# Solution goes here

# %% [markdown]
# ### Exercise
#
# Write an appropriately general set of functions that can draw flowers like this.
#
# ![](https://github.com/AllenDowney/ThinkPython/raw/v3/jupyturtle_flower.png)
#
# Hint: Use `arc` to write a function called `petal` that draws one flower petal.

# %%
# Solution goes here

def polyline(n, length, angle):
    for i in range(n):
        forward(length)
        left(angle)

def arc(radius, angle):
    arc_length = 2 * math.pi * radius * angle / 360
    # arc length is the circumference for the radius * the proportion of a full circle that is specified by the angle
    n = 30
    # number of steps
    length = arc_length / n
    # length is the length of each step
    step_angle = angle / n
    # step angle is how much the turtle turns each step
    polyline(n, length, step_angle)
    # calls the polyline function, which moves the turtle based on the number of steps, length of each step, and angle of each step
    # in summary the arc function makes the turtle move based on radius of the circle it it making and angle, which is how long the trail will be and how complete the circle is to be


def petal(radius, angle):
  arc(radius, angle)
  left(180-angle)
  arc(radius, angle)

make_turtle(delay = 0)
petal(60, 70)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="152.4" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.4" y1="75.0" x2="154.9" y2="74.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.9" y1="74.9" x2="157.3" y2="74.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.3" y1="74.7" x2="159.7" y2="74.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.7" y1="74.4" x2="162.2" y2="74.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.2" y1="74.0" x2="164.5" y2="73.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.5" y1="73.5" x2="166.9" y2="72.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="166.9" y1="72.9" x2="169.3" y2="72.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="169.3" y1="72.2" x2="171.6" y2="71.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="171.6" y1="71.5" x2="173.9" y2="70.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.9" y1="70.6" x2="176.1" y2="69.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="176.1" y1="69.6" x2="178.3" y2="68.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.3" y1="68.6" x2="180.5" y2="67.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.5" y1="67.4" x2="182.6" y2="66.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.6" y1="66.2" x2="184.6" y2="64.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="184.6" y1="64.9" x2="186.6" y2="63.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="186.6" y1="63.4" x2="188.6" y2="62.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.6" y1="62.0" x2="190.5" y2="60.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.5" y1="60.4" x2="192.3" y2="58.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.3" y1="58.8" x2="194.0" y2="57.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.0" y1="57.1" x2="195.7" y2="55.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="195.7" y1="55.3" x2="197.3" y2="53.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.3" y1="53.4" x2="198.8" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.8" y1="51.5" x2="200.3" y2="49.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.3" y1="49.6" x2="201.6" y2="47.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.6" y1="47.5" x2="202.9" y2="45.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.9" y1="45.5" x2="204.1" y2="43.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="204.1" y1="43.3" x2="205.2" y2="41.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="205.2" y1="41.2" x2="206.2" y2="38.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="206.2" y1="38.9" x2="207.2" y2="36.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="207.2" y1="36.7" x2="204.7" y2="36.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="204.7" y1="36.7" x2="202.3" y2="36.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.3" y1="36.8" x2="199.9" y2="37.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="199.9" y1="37.0" x2="197.4" y2="37.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.4" y1="37.3" x2="195.0" y2="37.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="195.0" y1="37.7" x2="192.6" y2="38.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.6" y1="38.2" x2="190.3" y2="38.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.3" y1="38.8" x2="187.9" y2="39.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="187.9" y1="39.4" x2="185.6" y2="40.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.6" y1="40.2" x2="183.3" y2="41.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.3" y1="41.1" x2="181.1" y2="42.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="181.1" y1="42.1" x2="178.9" y2="43.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.9" y1="43.1" x2="176.7" y2="44.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="176.7" y1="44.3" x2="174.6" y2="45.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="174.6" y1="45.5" x2="172.5" y2="46.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.5" y1="46.8" x2="170.5" y2="48.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.5" y1="48.2" x2="168.6" y2="49.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.6" y1="49.7" x2="166.7" y2="51.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="166.7" y1="51.3" x2="164.9" y2="52.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.9" y1="52.9" x2="163.2" y2="54.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="163.2" y1="54.6" x2="161.5" y2="56.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.5" y1="56.4" x2="159.9" y2="58.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.9" y1="58.2" x2="158.4" y2="60.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.4" y1="60.1" x2="156.9" y2="62.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.9" y1="62.1" x2="155.5" y2="64.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.5" y1="64.1" x2="154.3" y2="66.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.3" y1="66.2" x2="153.1" y2="68.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.1" y1="68.3" x2="151.9" y2="70.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.9" y1="70.5" x2="150.9" y2="72.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.9" y1="72.7" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(20.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
# Solution goes here
def flower(n, radius, angle):
  angle = 360/n
  for i in range(n):
    if n < 8:
      petal(radius, angle)
    else:
      petal(radius, angle*2)
    left(180)

make_turtle(delay=0)
flower(9, 40, 85)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="151.9" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.9" y1="75.0" x2="153.7" y2="74.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.7" y1="74.9" x2="155.6" y2="74.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.6" y1="74.7" x2="157.4" y2="74.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.4" y1="74.5" x2="159.2" y2="74.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.2" y1="74.1" x2="161.1" y2="73.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.1" y1="73.7" x2="162.8" y2="73.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.8" y1="73.2" x2="164.6" y2="72.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.6" y1="72.6" x2="166.3" y2="71.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="166.3" y1="71.9" x2="168.0" y2="71.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.0" y1="71.2" x2="169.7" y2="70.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="169.7" y1="70.3" x2="171.3" y2="69.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="171.3" y1="69.4" x2="172.9" y2="68.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.9" y1="68.4" x2="174.4" y2="67.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="174.4" y1="67.4" x2="175.9" y2="66.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.9" y1="66.2" x2="177.4" y2="65.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.4" y1="65.0" x2="178.7" y2="63.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.7" y1="63.8" x2="180.0" y2="62.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.0" y1="62.5" x2="181.3" y2="61.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="181.3" y1="61.1" x2="182.5" y2="59.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.5" y1="59.6" x2="183.6" y2="58.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.6" y1="58.1" x2="184.6" y2="56.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="184.6" y1="56.6" x2="185.6" y2="55.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.6" y1="55.0" x2="186.5" y2="53.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="186.5" y1="53.4" x2="187.3" y2="51.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="187.3" y1="51.7" x2="188.0" y2="50.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.0" y1="50.0" x2="188.7" y2="48.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.7" y1="48.3" x2="189.3" y2="46.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="189.3" y1="46.5" x2="189.7" y2="44.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="189.7" y1="44.7" x2="190.2" y2="42.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.2" y1="42.9" x2="188.3" y2="42.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.3" y1="42.9" x2="186.4" y2="43.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="186.4" y1="43.0" x2="184.6" y2="43.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="184.6" y1="43.1" x2="182.7" y2="43.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.7" y1="43.4" x2="180.9" y2="43.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="180.9" y1="43.7" x2="179.1" y2="44.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="179.1" y1="44.2" x2="177.3" y2="44.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="177.3" y1="44.7" x2="175.5" y2="45.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.5" y1="45.3" x2="173.8" y2="45.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.8" y1="45.9" x2="172.1" y2="46.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="172.1" y1="46.7" x2="170.4" y2="47.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.4" y1="47.5" x2="168.8" y2="48.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.8" y1="48.5" x2="167.2" y2="49.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="167.2" y1="49.4" x2="165.7" y2="50.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="165.7" y1="50.5" x2="164.2" y2="51.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.2" y1="51.6" x2="162.8" y2="52.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.8" y1="52.8" x2="161.4" y2="54.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.4" y1="54.1" x2="160.1" y2="55.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.1" y1="55.4" x2="158.9" y2="56.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.9" y1="56.8" x2="157.7" y2="58.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.7" y1="58.2" x2="156.6" y2="59.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="156.6" y1="59.7" x2="155.5" y2="61.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.5" y1="61.3" x2="154.6" y2="62.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.6" y1="62.9" x2="153.7" y2="64.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.7" y1="64.5" x2="152.9" y2="66.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.9" y1="66.2" x2="152.1" y2="67.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.1" y1="67.9" x2="151.5" y2="69.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.5" y1="69.6" x2="150.9" y2="71.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.9" y1="71.4" x2="150.4" y2="73.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.4" y1="73.2" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="150.3" y2="73.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.3" y1="73.2" x2="150.6" y2="71.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.6" y1="71.3" x2="150.7" y2="69.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.7" y1="69.5" x2="150.8" y2="67.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.8" y1="67.6" x2="150.8" y2="65.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.8" y1="65.7" x2="150.6" y2="63.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.6" y1="63.9" x2="150.5" y2="62.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.5" y1="62.0" x2="150.2" y2="60.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.2" y1="60.2" x2="149.8" y2="58.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="149.8" y1="58.4" x2="149.4" y2="56.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="149.4" y1="56.6" x2="148.8" y2="54.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="148.8" y1="54.8" x2="148.2" y2="53.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="148.2" y1="53.0" x2="147.5" y2="51.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="147.5" y1="51.3" x2="146.7" y2="49.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="146.7" y1="49.6" x2="145.9" y2="47.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="145.9" y1="47.9" x2="144.9" y2="46.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="144.9" y1="46.3" x2="143.9" y2="44.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.9" y1="44.8" x2="142.9" y2="43.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="142.9" y1="43.3" x2="141.7" y2="41.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.7" y1="41.8" x2="140.5" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.5" y1="40.4" x2="139.2" y2="39.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="139.2" y1="39.0" x2="137.9" y2="37.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="137.9" y1="37.7" x2="136.5" y2="36.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="136.5" y1="36.5" x2="135.0" y2="35.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="135.0" y1="35.3" x2="133.5" y2="34.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.5" y1="34.2" x2="132.0" y2="33.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="132.0" y1="33.2" x2="130.4" y2="32.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.4" y1="32.3" x2="128.7" y2="31.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.7" y1="31.4" x2="127.0" y2="30.6"
#     stroke="#663399" stroke-width="2"

# %% [markdown]
# You can use the following code to test your functions.
#
# Because the solution draws a lot of small line segments, it tends to slow down as it runs.
# To avoid that, you can add the keyword argument `auto_render=False` to avoid drawing after every step, and then call the `render` function at the end to show the result.
#
# While you are debugging, you might want to remove `auto_render=False`.

# %%
from jupyturtle import render

turtle = make_turtle(auto_render=False)

jump(-60)
n = 7
radius = 60
angle = 60
flower(n, radius, angle)

jump(100)
n = 9
radius = 40
angle = 85
flower(n, radius, angle)

render()
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="90.0" y1="75.0" x2="91.8" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="91.8" y1="75.0" x2="93.6" y2="74.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="93.6" y1="74.9" x2="95.4" y2="74.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="95.4" y1="74.8" x2="97.2" y2="74.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="97.2" y1="74.7" x2="99.0" y2="74.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="99.0" y1="74.5" x2="100.7" y2="74.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="100.7" y1="74.2" x2="102.5" y2="73.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.5" y1="73.9" x2="104.2" y2="73.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="104.2" y1="73.5" x2="106.0" y2="73.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="106.0" y1="73.1" x2="107.7" y2="72.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="107.7" y1="72.6" x2="109.4" y2="72.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="109.4" y1="72.1" x2="111.1" y2="71.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="111.1" y1="71.5" x2="112.8" y2="70.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="112.8" y1="70.9" x2="114.5" y2="70.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="114.5" y1="70.2" x2="116.1" y2="69.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="116.1" y1="69.4" x2="117.7" y2="68.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="117.7" y1="68.7" x2="119.3" y2="67.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="119.3" y1="67.8" x2="120.9" y2="67.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="120.9" y1="67.0" x2="122.4" y2="66.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="122.4" y1="66.0" x2="124.0" y2="65.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="124.0" y1="65.1" x2="125.4" y2="64.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="125.4" y1="64.1" x2="126.9" y2="63.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.9" y1="63.0" x2="128.3" y2="61.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.3" y1="61.9" x2="129.7" y2="60.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="129.7" y1="60.8" x2="131.0" y2="59.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.0" y1="59.6" x2="132.4" y2="58.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="132.4" y1="58.4" x2="133.6" y2="57.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.6" y1="57.1" x2="134.9" y2="55.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.9" y1="55.8" x2="136.1" y2="54.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="136.1" y1="54.5" x2="137.2" y2="53.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="137.2" y1="53.1" x2="135.4" y2="53.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="135.4" y1="53.1" x2="133.7" y2="53.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.7" y1="53.2" x2="131.9" y2="53.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.9" y1="53.3" x2="130.1" y2="53.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.1" y1="53.4" x2="128.3" y2="53.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.3" y1="53.6" x2="126.5" y2="53.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.5" y1="53.9" x2="124.8" y2="54.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="124.8" y1="54.2" x2="123.0" y2="54.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="123.0" y1="54.6" x2="121.3" y2="55.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="121.3" y1="55.0" x2="119.5" y2="55.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="119.5" y1="55.5" x2="117.8" y2="56.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="117.8" y1="56.0" x2="116.1" y2="56.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="116.1" y1="56.6" x2="114.4" y2="57.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="114.4" y1="57.3" x2="112.8" y2="57.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="112.8" y1="57.9" x2="111.1" y2="58.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="111.1" y1="58.7" x2="109.5" y2="59.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="109.5" y1="59.4" x2="107.9" y2="60.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="107.9" y1="60.3" x2="106.3" y2="61.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="106.3" y1="61.1" x2="104.8" y2="62.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="104.8" y1="62.1" x2="103.3" y2="63.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.3" y1="63.0" x2="101.8" y2="64.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="101.8" y1="64.0" x2="100.4" y2="65.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="100.4" y1="65.1" x2="98.9" y2="66.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="98.9" y1="66.2" x2="97.5" y2="67.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="97.5" y1="67.3" x2="96.2" y2="68.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="96.2" y1="68.5" x2="94.9" y2="69.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="94.9" y1="69.7" x2="93.6" y2="71.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="93.6" y1="71.0" x2="92.4" y2="72.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="92.4" y1="72.3" x2="91.2" y2="73.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="91.2" y1="73.6" x2="90.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="90.0" y1="75.0" x2="91.1" y2="73.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="91.1" y1="73.6" x2="92.2" y2="72.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="92.2" y1="72.2" x2="93.2" y2="70.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="93.2" y1="70.7" x2="94.2" y2="69.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="94.2" y1="69.2" x2="95.2" y2="67.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="95.2" y1="67.7" x2="96.1" y2="66.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="96.1" y1="66.1" x2="96.9" y2="64.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="96.9" y1="64.5" x2="97.7" y2="62.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="97.7" y1="62.9" x2="98.5" y2="61.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="98.5" y1="61.3" x2="99.2" y2="59.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="99.2" y1="59.6" x2="99.8" y2="58.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="99.8" y1="58.0" x2="100.4" y2="56.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="100.4" y1="56.3" x2="101.0" y2="54.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="101.0" y1="54.6" x2="101.5" y2="52.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="101.5" y1="52.9" x2="101.9" y2="51.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="101.9" y1="51.1" x2="102.3" y2="49.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.3" y1="49.4" x2="102.7" y2="47.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.7" y1="47.6" x2="103.0" y2="45.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.0" y1="45.8" x2="103.2" y2="44.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.2" y1="44.1" x2="103.4" y2="42.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.4" y1="42.3" x2="103.5" y2="40.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.5" y1="40.5" x2="103.6" y2="38.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.6" y1="38.7" x2="103.7" y2="36.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.7" y1="36.9" x2="103.6" y2="35.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.6" y1="35.1" x2="103.5" y2="33.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.5" y1="33.3" x2="103.4" y2="31.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.4" y1="31.5" x2="103.2" y2="29.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.2" y1="29.7" x2="103.0" y2="27.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.0" y1="27.9" x2="102.7" y2="26.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.7" y1="26.2" x2="102.3" y2=

# %%
# Solution goes here

# %% [markdown]
# ### Ask a virtual assistant
#
# There are several modules like `jupyturtle` in Python, and the one we used in this chapter has been customized for this book.
# So if you ask a virtual assistant for help, it won't know which module to use.
# But if you give it a few examples to work with, it can probably figure it out.
# For example, try this prompt and see if it can write a function that draws a spiral:
#
# ```
# The following program uses a turtle graphics module to draw a circle:
#
# from jupyturtle import make_turtle, forward, left
# import math
#
# def polygon(n, length):
#     angle = 360 / n
#     for i in range(n):
#         forward(length)
#         left(angle)
#
# def circle(radius):
#     circumference = 2 * math.pi * radius
#     n = 30
#     length = circumference / n
#     polygon(n, length)
#
# make_turtle(delay=0)
# circle(30)
#
# Write a function that draws a spiral.
# ```

# %% [markdown]
# Keep in mind that the result might use features we have not seen yet, and it might have errors.
# Copy the code from the VA and see if you can get it working.
# If you didn't get what you wanted, try modifying the prompt.

# %%
# Solution goes here
from jupyturtle import make_turtle, forward, left

def spiral(length, angle, scale):
    """Draws a spiral.

    length: the initial length of the first segment
    angle: the angle to turn after each segment
    scale: the factor by which to increase the length after each turn
    """
    for _ in range(25): # Draw 100 segments (you can adjust this)
        forward(length)
        left(angle)
        length *= scale

make_turtle(delay=0)
spiral(1, 90, 1.2)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="151.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.0" y1="75.0" x2="151.0" y2="73.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.0" y1="73.8" x2="149.6" y2="73.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="149.6" y1="73.8" x2="149.6" y2="75.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="149.6" y1="75.5" x2="151.6" y2="75.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.6" y1="75.5" x2="151.6" y2="73.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.6" y1="73.0" x2="148.6" y2="73.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="148.6" y1="73.0" x2="148.6" y2="76.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="148.6" y1="76.6" x2="152.9" y2="76.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.9" y1="76.6" x2="152.9" y2="71.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.9" y1="71.5" x2="146.8" y2="71.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="146.8" y1="71.5" x2="146.8" y2="78.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="146.8" y1="78.9" x2="155.7" y2="78.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.7" y1="78.9" x2="155.7" y2="68.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.7" y1="68.2" x2="142.8" y2="68.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="142.8" y1="68.2" x2="142.8" y2="83.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="142.8" y1="83.6" x2="161.3" y2="83.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.3" y1="83.6" x2="161.3" y2="61.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.3" y1="61.4" x2="134.7" y2="61.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.7" y1="61.4" x2="134.7" y2="93.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.7" y1="93.4" x2="173.0" y2="93.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.0" y1="93.4" x2="173.0" y2="47.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.0" y1="47.4" x2="117.8" y2="47.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="117.8" y1="47.4" x2="117.8" y2="113.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="117.8" y1="113.6" x2="197.3" y2="113.6"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(180.0,197.3,113.6) translate(197.3, 113.6)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
# Solution goes here

# %% [markdown]
# [Think Python: 3rd Edition](https://allendowney.github.io/ThinkPython/index.html)
#
# Copyright 2024 [Allen B. Downey](https://allendowney.com)
#
# Code license: [MIT License](https://mit-license.org/)
#
# Text license: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)

# %%
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="151.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.0" y1="75.0" x2="151.0" y2="74.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.0" y1="74.0" x2="149.9" y2="74.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="149.9" y1="74.0" x2="149.9" y2="75.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="149.9" y1="75.1" x2="151.1" y2="75.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.1" y1="75.1" x2="151.1" y2="73.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.1" y1="73.8" x2="149.8" y2="73.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="149.8" y1="73.8" x2="149.8" y2="75.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="149.8" y1="75.2" x2="151.3" y2="75.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.3" y1="75.2" x2="151.3" y2="73.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.3" y1="73.7" x2="149.6" y2="73.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="149.6" y1="73.7" x2="149.6" y2="75.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="149.6" y1="75.4" x2="151.4" y2="75.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.4" y1="75.4" x2="151.4" y2="73.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.4" y1="73.5" x2="149.4" y2="73.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="149.4" y1="73.5" x2="149.4" y2="75.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="149.4" y1="75.6" x2="151.6" y2="75.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.6" y1="75.6" x2="151.6" y2="73.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.6" y1="73.3" x2="149.2" y2="73.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="149.2" y1="73.3" x2="149.2" y2="75.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="149.2" y1="75.8" x2="151.9" y2="75.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.9" y1="75.8" x2="151.9" y2="73.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.9" y1="73.0" x2="148.9" y2="73.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="148.9" y1="73.0" x2="148.9" y2="76.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="148.9" y1="76.1" x2="152.2" y2="76.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.2" y1="76.1" x2="152.2" y2="72.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.2" y1="72.7" x2="148.6" y2="72.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="148.6" y1="72.7" x2="148.6" y2="76.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="148.6" y1="76.5" x2="152.5" y2="76.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.5" y1="76.5" x2="152.5" y2="72.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.5" y1="72.3" x2="148.2" y2="72.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="148.2" y1="72.3" x2="148.2" y2="76.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="148.2" y1="76.9" x2="153.0" y2="76.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.0" y1="76.9" x2="153.0" y2="71.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.0" y1="71.9" x2="147.7" y2="71.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="147.7" y1="71.9" x2="147.7" y2="77.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="147.7" y1="77.4" x2="153.5" y2="77.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.5" y1="77.4" x2="153.5" y2="71.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.5" y1="71.3" x2="147.1" y2="71.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="147.1" y1="71.3" x2="147.1" y2="78.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="147.1" y1="78.0" x2="154.2" y2="78.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.2" y1="78.0" x2="154.2" y2="70.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.2" y1="70.6" x2="146.4" y2="70.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="146.4" y1="70.6" x2="146.4" y2="78.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="146.4" y1="78.8" x2="155.0" y2="78.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.0" y1="78.8" x2="155.0" y2="69.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.0" y1="69.8" x2="145.5" y2="69.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="145.5" y1="69.8" x2="145.5" y2="79.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="145.5" y1="79.7" x2="155.9" y2="79.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.9" y1="79.7" x2="155.9" y2="68.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.9" y1="68.8" x2="144.5" y2="68.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="144.5" y1="68.8" x2="144.5" y2="80.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="144.5" y1="80.8" x2="157.1" y2="80.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.1" y1="80.8" x2="157.1" y2="67.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.1" y1="67.5" x2="143.2" y2="67.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.2" y1="67.5" x2="143.2" y2="82.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.2" y1="82.2" x2="158.5" y2="82.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.5" y1="82.2" x2="158.5" y2="66.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.5" y1="66.0" x2="141.6" y2="66.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.6" y1="66.0" x2="141.6" y2="83.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.6" y1="83.8" x2="160.3" y2="83.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.3" y1="83.8" x2="160.3" y2="64.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.3" y1="64.2" x2="139.7" y2="64.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="139.7" y1="64.2" x2="139.7" y2="85.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="139.7" y1="85.8" x2="162.4" y2="85.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.4" y1="85.8" x2="162.4" y2="62.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="162.4" y1="62.0" x2="137.3" y2="62.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="137.3" y1="62.0" x2="137.3" y2="88.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="137.3" y1="88.3" x2="164.9" y2="88.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.9" y1="88.3" x2="164.9" y2="59.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.9" y1="59.3" x2="134.5" y2="59.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.5" y1="59.3" x2="134.5" y2="91.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.5" y1="91.3" x2="168.1" y2="91.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.1" y1="91.3" x2="168.1" y2="56.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="168.1" y1="56.0" x2="131.1" y2="56.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.1" y1="56.0" x2="131.1" y2="94.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.1" y1="94.9" x2="171.9" y2="94.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="171.9" y1="94.9" x2="171.9" y2="52.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="171.9" y1="52.1" x2="126.9" y2="52.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.9" y1="52.1" x2="126.9" y2="99.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.9" y1="99.3" x2="176.5" y2="99.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="176.5" y1="99.3" x2="176.5" y2="47.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="176.5" y1="47.2" x2="121.8" y2="47.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="121.8" y1="47.2" x2="121.8" y2="104.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="121.8" y1="104.6" x2="182.1" y2="104.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.1" y1="104.6" x2="182.1" y2="41.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.1" y1="41.3" x2="115.6" y2="41.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="115.6" y1="41.3" x2="115.6" y2="111.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="115.6" y1="111.1" x2="188.9" y2="111.1"
#     stroke="#663399" stroke-wi
